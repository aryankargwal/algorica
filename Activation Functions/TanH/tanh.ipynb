# %%
# Importing Libraries
import numpy as np 
import math 
import matplotlib.pyplot as plt

# %%
# Defining Variables
x = np.linspace(-5,5,200)
y = np.tanh(x)

# %%
# Plotting the algorithm
plt.plot(x,y)
plt.show()
