# %%
# Importing Libraries
import numpy as np 
import math 
import matplotlib.pyplot as plt

# %%
# Defining Variables
x = np.linspace(-5, 5,100)
y = np.where(x > 0, x, x * 0.01) # Leaky ReLU condition

# %%
# Plotting the Algorithm
plt.plot(x,y)
