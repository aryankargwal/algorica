# %%
# Importing Libraries
import numpy as np 
import math 
import matplotlib.pyplot as plt

# %%
# RelU Function
def relu(X):
   return np.maximum(0,X)

# %%
# Defining Variables
x = np.linspace(-5, 5,100)
y = relu(x)

# %%
# Plotting the Algorithm
plt.plot(x,y)
